# %%
import sys
sys.path.insert(0, "/notebooks/pipenv")
sys.path.insert(0, "/notebooks/nebula3_vlm")
sys.path.insert(0, "/notebooks/nebula3_database")
sys.path.insert(0, "/notebooks/")
import os
import math
import random
import bisect
import pickle
import time
import copy
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib
import subprocess
import re
import tempfile
import itertools
import torch
import spacy
from torch.nn.functional import softmax as torch_softmax
from sumproduct import Variable, Factor, FactorGraph

from typing import List, Tuple
from operator import itemgetter 
from transformers import AutoModel, AutoTokenizer, AutoModelForSequenceClassification, BertTokenizer, BertForNextSentencePrediction
from database.arangodb import DatabaseConnector
from config import NEBULA_CONF
from movie_db import MOVIE_DB

# %%
class PIPELINE:
    def __init__(self):
        config = NEBULA_CONF()
        self.db_host = config.get_database_host()
        self.database = config.get_playground_name()
        self.gdb = DatabaseConnector()
        self.db = self.gdb.connect_db(self.database)

pipeline = PIPELINE()
mdb = MOVIE_DB()
from vlm.clip_api import CLIP_API
clip=CLIP_API('vit')
s2_collection_name = 's2_pipeline_after_gpt'
s2_results_orig_collection_name = 's2_pipeline_optim_orig'
s2_results_relaxed_collection_name = 's2_pipeline_optim_relaxed'
s2_compatibility_collection_name = 's2_pipeline_compatibility_scores'

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForNextSentencePrediction.from_pretrained('bert-base-uncased')
device = "cuda:0"
model = model.to(device)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForNextSentencePrediction: ['cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForNextSentencePrediction from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForNextSentencePrediction from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def create_2chain_graph(factors):
    g = FactorGraph(silent=True)  # init the graph without message printouts
    num_vars = len(factors)+1
    vars = []
    vnames = []
    gvars = []
    for i in range(len(factors)-1):
        assert factors[i].shape[1] == factors[i+1].shape[0]
        vars.append(factors[i].shape[0])
    vars.append(factors[-1].shape[0])
    vars.append(factors[-1].shape[1])
    for i, v_size in enumerate(vars):
        vname = 'x'+str(i+1)
        v = Variable(vname, v_size)
        vnames.append(vname)
        gvars.append(v)

    for i in range(len(gvars)-1):
        fname = 'f{}{}'.format(i+1, i+2)
        # factors are transposed, from x2 to x1, etc'
        fact = Factor(fname, factors[i].transpose())
        g.add(fact)
        g.append(fname, gvars[i+1])
        g.append(fname, gvars[i])

    return g, vnames


def create_3chain_graph(factors):
    g = FactorGraph(silent=True)  # init the graph without message printouts
    num_vars = len(factors)+2
    vars = []
    vnames = []
    gvars = []
    for i in range(len(factors)-2):
        assert factors[i].shape[1] == factors[i+1].shape[0]
        assert factors[i].shape[2] == factors[i+1].shape[1]
        assert factors[i].shape[2] == factors[i+2].shape[0]
        vars.append(factors[i].shape[0])
    vars.append(factors[-2].shape[0])
    vars.append(factors[-2].shape[1])
    vars.append(factors[-2].shape[2])
    vars.append(factors[-1].shape[2])
    for i, n in enumerate(vars):
        vname = 'x'+str(i+1)
        v = Variable(vname, n)
        vnames.append(vname)
        gvars.append(v)
    for i in range(len(gvars)-2):
        fname = 'f{}{}{}'.format(i+1, i+2, i+3)
        fact = Factor(fname, factors[i].transpose(
            2, 1, 0))     # factors are transposed
        g.add(fact)
        g.append(fname, gvars[i+2])
        g.append(fname, gvars[i+1])
        g.append(fname, gvars[i])

    return g, vnames

def compute_marginals(factors, chain_creator):
    g, vnames = chain_creator(factors)
    g.compute_marginals(max_iter=15500, tolerance=1e-8)
    rc = []
    for vname in vnames:
        rc.append(g.nodes[vname].marginal())
    return rc

def compute_2chain_marginals(factors):
    return compute_marginals(factors, create_2chain_graph)


def compute_3chain_marginals(factors):
    return compute_marginals(factors, create_3chain_graph)

# def compute_2chain_marginals_orig(factors):
#     g, vnames = create_2chain_graph(factors)
#     g.compute_marginals(max_iter=15500, tolerance=1e-8)
#     rc = []
#     for vname in vnames:
#         rc.append(g.nodes[vname].marginal())
#     return rc

# Input: A list of list of strings
# Output: A list of list of scores

def story_compatability(scene1, scene2):
    rows_ = []
    for sent_a in scene1:
        cols_ = []
        for sent_b in scene2:
            encoded = tokenizer.encode_plus(sent_a, sent_b, return_tensors='pt').to(device)
            seq_relationship_logits = model(**encoded)[0]
            probs = torch_softmax(seq_relationship_logits, dim=1)
            score = probs[0][0].tolist()
            cols_.append(score)
        rows_.append(cols_)
    return(np.array(rows_))


def score_story(story):
    scenes_scores = []   # factors
    for idx in range(0, len(story) -1):
        scene1 = story[idx]
        scene2 = story[idx + 1]
        scene_matrix = story_compatability(scene1, scene2)
        scenes_scores.append(scene_matrix)

    return compute_2chain_marginals(scenes_scores)

# %%
flatten = lambda lst: [x for l in lst for x in l]
softmax = lambda x: np.exp(x)/sum(np.exp(x))
def normalize(x):
    epsilon = 0.00001
    if np.std(x) < epsilon:
        return np.ones(x.shape)
    return (x - np.mean(x)) / np.std(x)

# %%
query = 'FOR doc IN {} RETURN doc'.format(s2_results_relaxed_collection_name)
cursor = pipeline.db.aql.execute(query)
all_docs = list(cursor)

# %%
movies = list(set([x['movie_id'] for x in all_docs]))
all_movies = {}

for mid in movies:
    print("mid is {}".format(mid))
    story = []
    elements = copy.deepcopy(sorted([x for x in all_docs if x['movie_id'] == mid],key=lambda y:y['scene_element']))
    all_movies[mid] = elements
    # n = len(elements[0]['sentences'])    # Number of copies
    n = 3
    random_elem_index = np.random.choice(range(len(elements)))
    random_sentence = None
    while random_sentence is None:
        doc = np.random.choice(all_docs)
        if doc['movie_id']==mid:
            continue
        try:
            random_sentence=np.random.choice(doc['sentences'][0]).copy()
        except Exception as e:
            print('Damn, error')
            print(doc)
    print("Added random sentence to mid {} at scene {}:".format(mid,random_elem_index))
    print(random_sentence)
    elements[random_elem_index]['sentences'][0].append(random_sentence)
    print('Number of copies is n={}'.format(n))
    for i in range(n):
        print("copy number {}".format(i))
        story=[elem['sentences'][i] for elem in elements]
        marginals = score_story(story)
        for (elem,story_part_score) in zip(elements,marginals):
            elem['sentences'][i]=list(zip(elem['sentences'][i],story_part_score))     # Update scene_element with scores
# Out:
# mid is Movies/222510046
# Added random sentence to mid Movies/222510046 at scene 1:
# two men in wetsuits holding a group of missiles from behind and looking out at the sea and the sky
# Number of copies is n=3
# copy number 0
# copy number 1
# copy number 2
# mid is Movies/222511030
# Added random sentence to mid Movies/222511030 at scene 2:
# an old talking man with a beard is looking at you
# Number of copies is n=3
# copy number 0
# copy number 1
# copy number 2
# mid is Movies/222509721
# Added random sentence to mid Movies/222509721 at scene 0:
# A group of beautiful women wearing red clothing and holding wine glasses are walking next to each other.
# Number of copies is n=3
# copy number 0
# copy number 1
# copy number 2
# mid is Movies/222510448
# Added random sentence to mid Movies/222510448 at scene 2:
# a group of people with dark long hair and bearded in suits in a movie
# Number of copies is n=3
# copy number 0
# copy number 1
# copy number 2
# mid is Movies/222509634
# Added random sentence to mid Movies/222509634 at scene 1:
# a dark skinned girl in a white shirt is performing kong fu in front of a crowd
# Number of copies is n=3
# copy number 0
# copy number 1
# copy number 2
# mid is Movies/222510189
# Added random sentence to mid Movies/222510189 at scene 2:
# a group of young men in black shirts are watching asian men
# Number of copies is n=3
# copy number 0
# copy number 1
# copy number 2
# mid is Movies/222510403
# Added random sentence to mid Movies/222510403 at scene 1:
# A man with a tie sitting at a desk in front of a computer and drawing a staircase
# Number of copies is n=3
# copy number 0
# copy number 1
# copy number 2
# mid is Movies/222510324
# Added random sentence to mid Movies/222510324 at scene 4:
# a man in a white shirt in the front of a cupboard and a lamp behind him talks to a girl
# Number of copies is n=3
# copy number 0
# copy number 1
# copy number 2
# mid is Movies/222511095
# Added random sentence to mid Movies/222511095 at scene 2:
# A woman with long hair eat and looking down at her hand in the dark in the woods, where she sleep
# Number of copies is n=3
# copy number 0
# copy number 1
# copy number 2
# mid is Movies/222509945
# Added random sentence to mid Movies/222509945 at scene 4:
# a person sitting over tables in a caffe at night
# Number of copies is n=3
# copy number 0
# copy number 1
# copy number 2
# mid is Movies/222510136
# Added random sentence to mid Movies/222510136 at scene 0:
# a young girl in a striped shirt is standing in the middle of rocky mountains at the back
# Number of copies is n=3
# copy number 0
# copy number 1
# copy number 2
# mid is Movies/222510692
# Added random sentence to mid Movies/222510692 at scene 0:
# a hand is holding car keys on a handle near car door
# Number of copies is n=3
# copy number 0
# copy number 1
# copy number 2
# mid is Movies/222510575
# Added random sentence to mid Movies/222510575 at scene 0:
# a man with sun glasses, hat and others are holding guns on the street at night near several parked cars
# Number of copies is n=3
# copy number 0
# copy number 1
# copy number 2
# mid is Movies/222510253
# Added random sentence to mid Movies/222510253 at scene 0:
# A woman standing next to another beautiful woman at a social event.
# Number of copies is n=3
# copy number 0
# copy number 1
# copy number 2
# mid is Movies/222510810
# Added random sentence to mid Movies/222510810 at scene 6:
# A group of men in hats hold someone down in the dark
# Number of copies is n=3
# copy number 0
# copy number 1
# copy number 2
# mid is Movies/222509871
# Added random sentence to mid Movies/222509871 at scene 1:
# Four teenagers in black and yellow swim suits are standing on a field with a red-headed boy wearing a dark mask.
# Number of copies is n=3
# copy number 0
# copy number 1
# copy number 2
# mid is Movies/222509820
# Added random sentence to mid Movies/222509820 at scene 5:
# two men in black and yellow wetsuits looking away from each other alerted
# Number of copies is n=3
# copy number 0
# copy number 1
# copy number 2
# mid is Movies/222510951
# Added random sentence to mid Movies/222510951 at scene 3:
# A woman in a red beautiful dress is standing in a room in the night in a gathering
# Number of copies is n=3
# copy number 0
# copy number 1
# copy number 2

# %%
# movies = list(set([x['movie_id'] for x in all_docs]))[:2]
# all_movies = {}

# for mid in movies:
#     print("mid is {}".format(mid))
#     story = []
#     elements = sorted([x for x in all_docs if x['movie_id'] == mid],key=lambda y:y['scene_element'])
#     all_movies[mid] = elements
#     n = len(elements[0]['sentences'])    # Number of copies
#     print('Number of copies is n={}'.format(n))
#     for i in range(n):
#         print("copy number {}".format(i))
#         story=[elem['sentences'][i] for elem in elements]
#         marginals = score_story(story)
#         for (elem,story_part_score) in zip(elements,marginals):
#             elem['sentences'][i]=list(zip(elem['sentences'][i],story_part_score))     # Update scene_element with scores

# %%
all_movies['Movies/222510692'][0]
# Out:
# {'_key': '223847931',
#  '_id': 's2_pipeline_optim_relaxed/223847931',
#  '_rev': '_ePM62eC---',
#  'movie_id': 'Movies/222510692',
#  'scene_element': 0,
#  'sentences': [[('a group of birds flying over a flat arid area with a fire in the corner and a herd of cattle',
#     0.08335114112022529),
#    ('"a herd of cattle in a deep canyon crossing an arid flat area"',
#     0.08335089768214698),
#    ('A group of birds flying over a deep canyon, over flat arid area, and over a herd of cattle',
#     0.08335111131140942),
#    ('"a group of running birds over a deep canyon in the flat arid area"',
#     0.08325418261451431),
#    ('"a group of birds flying over a deep canyon with strange shapes in a arid flat area"',
#     0.08327345897140814),
#    ('"a group of birds running over a deep canyon with a fire in the corner"',
#     0.08332008409199562),
#    ('"a group of running herd of cattle near a burning fire in the corner"',
#     0.08334978152428303),
#    ('"a group of birds flying over a herd of cattle in a deep canyon and running',
#     0.08335104589805403),
#    ('"a group of birds flying over a deep canyon with some fire in the corner, and a herd of cattle"',
#     0.08335030481817185),
#    ('"a group of birds flying over a flat arid area with a fire in the corner and a herd of cattle"',
#     0.08335098296853952),
#    ('"a group of birds flying over a deep canyon with a flat arid area in the background with a fire in the corner"',
#     0.08334836351861456),
#    ('a hand is holding car keys on a handle near car door',
#     0.08334864548063729)],
#   [('a group of birds flying over a flat arid area with a fire in the corner and a herd of cattle',
#     0.09094483980110718),
#    ('"a herd of cattle in a deep canyon crossing an arid flat area"',
#     0.09094459948130182),
#    ('A group of birds flying over a deep canyon, over flat arid area, and over a herd of cattle',
#     0.09094482444229891),
#    ('a herd of cattle is running in a deep canyon while a group of birds flying over a waterfall',
#     0.09094483618722032),
#    ('"a group of running birds over a deep canyon in the flat arid area"',
#     0.09077954401208636),
#    ('"a group of birds running over a deep canyon with a fire in the corner"',
#     0.09071919256132994),
#    ('"a group of birds flying over a herd of cattle in a deep canyon and running',
#     0.09094472144806072),
#    ('"a group of birds flying over a deep canyon with some fire in the corner, and a herd of cattle"',
#     0.09094389117056262),
#    ('"a group of birds flying over a flat arid area with a fire in the corner and a herd of cattle"',
#     0.09094467988915052),
#    ('"a group of birds flying over a herd of running cattle on a flat arid area"',
#     0.0909445796054298),
#    ('A group of birds running over a deep canyon with a fire in the corner',
#     0.09094429140145181)],
#   [('a group of birds flying over a flat arid area with a fire in the corner and a herd of cattle',
#     0.09091037702084313),
#    ('"a herd of cattle in a deep canyon crossing an arid flat area"',
#     0.09091016716919956),
#    ('a herd of cattle is running in a deep canyon while a group of birds flying over a waterfall',
#     0.09091038687309054),
#    ('"a group of running birds over a deep canyon in the flat arid area"',
#     0.09090828835675274),
#    ('"a group of birds running over a deep canyon with a fire in the corner"',
#     0.09090119726431631),
#    ('"a group of birds flying over a herd of cattle in a deep canyon and running',
#     0.09091027357289364),
#    ('"a group of running birds flying over a deep canyon over flat arid area"',
#     0.09090913465945961),
#    ('a group of people are running in a flat arid area near a burning town',
#     0.09091027652842495),
#    ('"a group of birds flying over a deep canyon with some fire in the corner, and a herd of cattle"',
#     0.09090937308386611),
#    ('"a group of birds flying over a flat arid area with a fire in the corner and a herd of cattle"',
#     0.09091027258778232),
#    ('"a group of birds flying over a herd of running cattle on a flat arid area"',
#     0.09091025288337116)],
#   ['"a herd of cattle in a deep canyon crossing an arid flat area"',
#    'A group of birds flying over a deep canyon, over flat arid area, and over a herd of cattle',
#    'a herd of cattle is running in a deep canyon while a group of birds flying over a waterfall',
#    '"a group of running birds over a deep canyon in the flat arid area"',
#    '"a group of birds flying over a deep canyon with strange shapes in a arid flat area"',
#    '"a group of birds flying over a herd of cattle in a deep canyon and running',
#    '"a group of running birds flying over a deep canyon over flat arid area"',
#    '"a group of birds flying over a deep canyon with some fire in the corner, and a herd of cattle"',
#    '"a group of birds flying over a flat arid area with a fire in the corner and a herd of cattle"',
#    '"a group of birds flying over a deep canyon with a flat arid area in the background with a fire in the corner"',
#    '"a group of running birds under a hot sky in the flat arid area with a fire in the corner"'],
#   ['"a herd of cattle in a deep canyon crossing an arid flat area"',
#    'A group of birds flying over a deep canyon, over flat arid area, and over a herd of cattle',
#    '"a group of running birds over a deep canyon in the flat arid area"',
#    '"a group of birds flying over a deep canyon with strange shapes in a arid flat area"',
#    '"a group of birds running over a deep canyon with a fire in the corner"',
#    '"a group of birds flying over a herd of cattle in a deep canyon and running',
#    '"a group of running birds flying over a deep canyon over flat arid area"',
#    'a group of people are running in a flat arid area near a burning town',
#    '"a group of birds flying over a deep canyon with some fire in the corner, and a herd of cattle"',
#    '"a group of birds flying over a flat arid area with a fire in the corner and a herd of cattle"',
#    'a herd of cattle running in a flat arid area under a gray sky with fast approaching dark clouds'],
#   ['a group of birds flying over a flat arid area with a fire in the corner and a herd of cattle',
#    '"a herd of cattle in a deep canyon crossing an arid flat area"',
#    'A group of birds flying over a deep canyon, over flat arid area, and over a herd of cattle',
#    '"a group of running birds over a deep canyon in the flat arid area"',
#    '"a group of birds flying over a deep canyon with a fire in the corner"',
#    '"a group of birds running over a deep canyon with a fire in the corner"',
#    '"a group of birds flying over a herd of cattle in a deep canyon and running',
#    '"a group of running birds flying over a deep canyon over flat arid area"',
#    '"a group of birds flying over a deep canyon with some fire in the corner, and a herd of cattle"',
#    '"a group of birds flying over a flat arid area with a fire in the corner and a herd of cattle"',
#    '"a group of birds flying over a deep canyon with a flat arid area in the background with a fire in the corner"'],
#   ['"a herd of cattle in a deep canyon crossing an arid flat area"',
#    '"a group of running birds over a flat arid area"',
#    '"a group of birds flying over a deep canyon with strange shapes in a arid flat area"',
#    '"a group of birds flying over a deep canyon with a fire in the corner"',
#    '"a group of birds flying over a flat arid area, with a herd of cattle"',
#    '"a group of birds flying over a herd of cattle in a deep canyon and running',
#    '"a group of running birds flying over a deep canyon over flat arid area"',
#    'a group of people are running in a flat arid area near a burning town',
#    '"a group of herd of cattle crossing a deep canyon under a sunny sky"',
#    '"a group of birds flying over a deep canyon with some fire in the corner, and a herd of cattle"',
#    '"a group of birds flying over a herd of cattle on a flat arid area"',
#    '" a group of running birds flying over a deep canyon"'],
#   ['a group of birds flying over a flat arid area with a fire in the corner and a herd of cattle',
#    'A group of birds flying over a deep canyon, over flat arid area, and over a herd of cattle',
#    'a herd of cattle is running in a deep canyon while a group of birds flying over a waterfall',
#    '"a group of running birds over a deep canyon in the flat arid area"',
#    '"a group of birds running over a deep canyon with a fire in the corner"',
#    '"a group of running herd of cattle near a burning fire in the corner"',
#    '"a group of birds flying over a herd of cattle in a deep canyon and running',
#    '"a group of birds flying over a deep canyon with some fire in the corner, and a herd of cattle"',
#    '"a group of birds flying over a flat arid area with a fire in the corner and a herd of cattle"',
#    '"a group of birds flying over a herd of running cattle on a flat arid area"',
#    '"a group of running birds under a hot sky in the flat arid area with a fire in the corner"'],
#   ['"a herd of cattle in a deep canyon crossing an arid flat area"',
#    'a herd of cattle is running in a deep canyon while a group of birds flying over a waterfall',
#    '"a group of running birds over a deep canyon in the flat arid area"',
#    '"a group of birds running over a deep canyon with a fire in the corner"',
#    '"a group of birds flying in the deep canyon in the arid area with a fire in the corner"',
#    '"a group of birds flying over a flat arid area, with a herd of cattle"',
#    '"a group of birds flying over a herd of cattle in a deep canyon and running',
#    '"a group of running birds flying over a deep canyon over flat arid area"',
#    '"a group of birds flying over a deep canyon with some fire in the corner, and a herd of cattle"',
#    '"a group of birds flying over a flat arid area with a fire in the corner and a herd of cattle"',
#    '"a group of birds flying over a deep canyon with a flat arid area in the background with a fire in the corner"'],
#   ['a group of birds flying over a flat arid area with a fire in the corner and a herd of cattle',
#    '"a herd of cattle in a deep canyon crossing an arid flat area"',
#    '"a group of running birds over a deep canyon in the flat arid area"',
#    '"a group of birds running over a deep canyon with a fire in the corner"',
#    '"a group of running herd of cattle near a burning fire in the corner"',
#    '"a group of birds flying in the deep canyon in the arid area with a fire in the corner"',
#    '"a group of birds flying over a herd of cattle in a deep canyon and running',
#    '"a group of birds flying over a deep canyon with some fire in the corner, and a herd of cattle"',
#    '"a group of birds flying over a flat arid area with a fire in the corner and a herd of cattle"',
#    'a herd of cattle running in a flat arid area under a gray sky with fast approaching dark clouds',
#    '"a group of birds flying over a deep canyon with a flat arid area in the background with a fire in the corner"']],
#  'mean_scores': [0.2195,
#   0.2175,
#   0.2146,
#   0.2144,
#   0.2147,
#   0.2178,
#   0.2104,
#   0.211,
#   0.2162,
#   0.212]}

# %%
story_obj = all_movies[list(all_movies.keys())[1]]
story = [x['sentences'][0] for x in story_obj]
rc = score_story(story)

# %%
list(zip('abcd',rc[0]))
