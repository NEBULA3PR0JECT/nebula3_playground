# %%
import sys
sys.path.insert(0, "/notebooks")
sys.path.insert(0, "/notebooks/pipenv")
sys.path.insert(0, "/notebooks/nebula3_database")
from torch.nn.functional import softmax
from transformers import BertTokenizer, BertForNextSentencePrediction
import torch
import random
import csv
import numpy as np
from sumproduct import Variable, Factor, FactorGraph
import pickle

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForNextSentencePrediction.from_pretrained('bert-base-uncased')
device = "cuda:0"
model = model.to(device)
# Out:
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/420M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForNextSentencePrediction: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForNextSentencePrediction from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForNextSentencePrediction from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_1909/3593278500.py in <module>
#       2 model = BertForNextSentencePrediction.from_pretrained('bert-base-uncased')
#       3 device = "cuda:0"
# ----> 4 model = model.to(device)
#
# /opt/conda/envs/nebula/lib/python3.10/site-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#     905             return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#     906
# --> 907         return self._apply(convert)
#     908
#     909     def register_backward_hook(
#
# /opt/conda/envs/nebula/lib/python3.10/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     576     def _apply(self, fn):
#     577         for module in self.children():
# --> 578             module._apply(fn)
#     579
#     580         def compute_should_use_set_data(tensor, tensor_applied):
#
# /opt/conda/envs/nebula/lib/python3.10/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     576     def _apply(self, fn):
#     577         for module in self.children():
# --> 578             module._apply(fn)
#     579
#     580         def compute_should_use_set_data(tensor, tensor_applied):
#
# /opt/conda/envs/nebula/lib/python3.10/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     576     def _apply(self, fn):
#     577         for module in self.children():
# --> 578             module._apply(fn)
#     579
#     580         def compute_should_use_set_data(tensor, tensor_applied):
#
# /opt/conda/envs/nebula/lib/python3.10/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     599             # `with torch.no_grad():`
#     600             with torch.no_grad():
# --> 601                 param_applied = fn(param)
#     602             should_use_set_data = compute_should_use_set_data(param, param_applied)
#     603             if should_use_set_data:
#
# /opt/conda/envs/nebula/lib/python3.10/site-packages/torch/nn/modules/module.py in convert(t)
#     903                 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#     904                             non_blocking, memory_format=convert_to_format)
# --> 905             return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#     906
#     907         return self._apply(convert)
#
# /opt/conda/envs/nebula/lib/python3.10/site-packages/torch/cuda/__init__.py in _lazy_init()
#     214         # This function throws if there's a driver initialization error, no GPUs
#     215         # are found or any other error occurs
# --> 216         torch._C._cuda_init()
#     217         # Some of the queued calls may reentrantly call _lazy_init();
#     218         # we need to just return without initializing in that case.
#
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx

# %%
def load_stories(dataset = 'roc'):
    if dataset ==  'roc':
        stories = []
        with open("1000ROC.csv") as file:
            tsv_file = csv.reader(file, delimiter=",")
            for line in tsv_file:
                #print(line)
                line.pop(0)
                #print(line)
                line.pop(0)
                stories.append(line)
    return(stories)

# %%
def create_stories(stories):
    stories_with_candidates = []
    for story in stories:
        story_length = len(story) - 1
        corpus_length = len(stories) -1
        scenes = []
        #print(orig_story[0])
        for sentence in story:
            candidates = []
            candidates.append(sentence)
            for candidate in range(0, random.randint(3, 10 )):
                cand_sent = random.randint(0, story_length)
                cand_story = random.randint(0, corpus_length)
                candidates.append(stories[cand_story][cand_sent])
            scenes.append(candidates)
        stories_with_candidates.append(scenes)
    return(stories_with_candidates)

# %%
def story_compatability(scene1, scene2):
    rows_ = []
    for sent_a in scene1:
        cols_ = []
        for sent_b in scene2:
            encoded = tokenizer.encode_plus(sent_a, sent_b, return_tensors='pt').to(device)
            seq_relationship_logits = model(**encoded)[0]
            probs = softmax(seq_relationship_logits, dim=1)
            score = probs[0][0].tolist()
            cols_.append(score)
        rows_.append(cols_)
    return(np.array(rows_))

# %%
stories = load_stories('roc')
candidated_stories = create_stories(stories)
stories_with_scores = []
for story in candidated_stories:
    scenes_scores = []
    for idx in range(0, len(story) -1):
        scene1 = story[idx]
        scene2 = story[idx + 1]
        scene_matrix = story_compatability(scene1, scene2)
        scenes_scores.append(scene_matrix)
    storie_with_scores = {
        'story': story,
        'scores': scenes_scores
    }

    stories_with_scores.append(storie_with_scores)

# %%
with open('roc1k.pickle', 'wb') as handle:
    pickle.dump(stories_with_scores, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# for i in stories_with_scores:
#     print(i)

# %%
stories_with_scores_saved = pickle.load( open( "roc10.pickle", "rb" ) )

# %%
# factors: an array of 2d factor matrices, for x12, x23, ..., where dimensions are x1*x2, x2*x3, ...

def create_2chain_graph(factors):
    g = FactorGraph(silent=True)  # init the graph without message printouts
    num_vars = len(factors)+1
    vars = []
    vnames = []
    gvars = []
    for i in range(len(factors)-1):
        assert factors[i].shape[1] == factors[i+1].shape[0]
        vars.append(factors[i].shape[0])
    vars.append(factors[-1].shape[0])
    vars.append(factors[-1].shape[1])
    for i, v_size in enumerate(vars):
        vname = 'x'+str(i+1)
        v = Variable(vname, v_size)
        vnames.append(vname)
        gvars.append(v)

    for i in range(len(gvars)-1):
        fname = 'f{}{}'.format(i+1, i+2)
        # factors are transposed, from x2 to x1, etc'
        fact = Factor(fname, factors[i].transpose())
        g.add(fact)
        g.append(fname, gvars[i+1])
        g.append(fname, gvars[i])

    return g, vnames


def compute_2chain_marginals(factors):
    g, vnames = create_2chain_graph(factors)
    g.compute_marginals(max_iter=15500, tolerance=1e-8)
    rc = []
    for vname in vnames:
        rc.append(g.nodes[vname].marginal())
    return rc

# %%
for story in stories_with_scores_saved:
    rc = compute_2chain_marginals(story['scores'])
    print('Story with candidates (First sentence is each array is good)')
    print(story['story'])
    print('BERT Scores')
    print(story['scores'])
    print('Marginals')
    print(rc)
# Out:
# Story with candidates (First sentence is each array is good)
# [["Dan's parents were overweight.", 'Then finally, one of her paintings took first place!', "She wanted some new friends, but wasn't sure where to look.", 'Then, it began to rain.', 'There was a big race coming up.', 'Bob had to pay a fine and realize he should not drink and drive.', 'Jonas has felt depressed that it has been very cold lately.', 'Undecided what to do with his life being recently let go of his job.', 'The cat woke up angrily and hissed.', 'The cashier asks Simon what he would like to order.'], ['Dan was overweight as well.', 'So when his sister bought a cat, he became annoyed.', 'There was a triple open, but only for a 6-letter word starting with z.', 'Mary had always gotten good grades in school, but failed a test.', 'We were told to leave the theatre and the beer was confiscated.', 'Ro was very happy.', 'He decided to seek work.', 'My father always worried about me because he thought I was addicted.', 'Sometimes it can be hard to choose where to sit.', 'She spent the entire evening sneezing and blowing her nose.', 'When she arrived at her new apartment she unpacked all her things.'], ['The doctors told his parents it was unhealthy.', 'Linda has never voted in any election.', 'Mable wanted to make something for me to eat.', 'She thought she was confessing to the old parish priest.', 'She decided to go to the show anyway.', 'I was very thirsty after dinner.', 'She discovered that a white piece kept breaking off.', 'He was rude.', 'One day, a really cute cashier gave me three packets of ketchup.', 'Thankfully she picked up a bottle of  Moroccanoil.'], ['His parents understood and decided to make a change.', 'Jill felt glad that she got all her homework done on time.', 'Finally, the sign laid flat and looked normal.', "Gina came home to find her mom's cousin Sherry was visiting.", 'She dusts on Monday.', "A bus driver wanted to save gas so he didn't come to a full stop.", 'We decided to help her celebrate.', 'They had to walk around for an hour before eating.'], ['They got themselves and Dan on a diet.', 'Sam needed to go to work one snowy morning', 'John puts cream and sugar in his cup and thermos.', 'They decided to go downtown.', 'Everyone was mad, but we had to go outside.', 'She picked out designs she liked.', 'Lebron got a new coach last season.', 'Charles turned on the television and watched the show on time.', 'He did his best and got an A.', 'She was planning on moving on California.', 'Mark packed up his equipment and went home.']]
# BERT Scores
# [array([[9.99996901e-01, 9.99986768e-01, 1.15353236e-04, 9.99966264e-01,
#         1.87173125e-03, 5.27463097e-04, 9.99878764e-01, 9.94996309e-01,
#         1.32804317e-03, 6.32900628e-05, 7.00425517e-05],
#        [4.67510690e-04, 8.52794969e-04, 2.03823508e-03, 9.99784768e-01,
#         1.81664377e-02, 9.99974608e-01, 5.00076124e-03, 1.08718152e-04,
#         2.67356262e-03, 9.99607503e-01, 9.99338686e-01],
#        [9.75604653e-01, 2.14799235e-04, 4.70391242e-04, 9.99924183e-01,
#         2.94884871e-04, 9.99309897e-01, 9.38239682e-05, 3.00418105e-05,
#         9.97863829e-01, 9.99902606e-01, 9.99948621e-01],
#        [1.17203090e-04, 3.28172973e-05, 9.02251049e-04, 1.66686978e-02,
#         9.99817431e-01, 9.98120964e-01, 9.97019947e-01, 1.11998997e-04,
#         8.04005103e-05, 9.99207199e-01, 9.91100609e-01],
#        [9.99569833e-01, 4.72449558e-03, 9.99965191e-01, 6.65168583e-01,
#         9.99958992e-01, 9.99968529e-01, 9.99411583e-01, 3.88003595e-04,
#         8.01944872e-04, 7.87335634e-03, 5.21903858e-02],
#        [9.99940991e-01, 9.99985218e-01, 3.02409491e-04, 9.98817503e-01,
#         9.99964476e-01, 9.97725427e-01, 9.99985456e-01, 2.43470166e-02,
#         5.33342687e-03, 4.16299357e-04, 1.87321345e-03],
#        [2.92820623e-05, 9.99929309e-01, 3.13449164e-05, 9.56974764e-05,
#         1.90076273e-04, 9.92974019e-05, 9.99821246e-01, 1.30637942e-04,
#         9.99665856e-01, 5.20375470e-05, 2.40663983e-04],
#        [9.99568522e-01, 9.99939442e-01, 1.56123133e-04, 5.12142014e-03,
#         6.16258360e-04, 1.25149250e-01, 9.99990582e-01, 2.01296643e-04,
#         9.99262989e-01, 4.59951298e-05, 5.46528085e-04],
#        [8.26043761e-05, 9.99959588e-01, 3.30683484e-04, 3.90486955e-03,
#         3.51098191e-04, 9.97484088e-01, 1.75544359e-02, 1.43093028e-04,
#         1.25605264e-04, 9.99972343e-01, 8.73602752e-04],
#        [2.21775936e-05, 4.63388860e-05, 6.99378943e-05, 5.35073486e-05,
#         4.41393277e-05, 6.57483237e-04, 2.14727588e-05, 3.53098912e-05,
#        0.12465565, 0.04420159, 0.06049201, 0.09664382, 0.01977164]), array([0.05781292, 0.07652469, 0.01609312, 0.11705638, 0.08093945,
#        0.22180227, 0.05486541, 0.02353903, 0.07923089, 0.17990486,
#        0.09223097]), array([0.14718272, 0.12360987, 0.06734596, 0.08422745, 0.17194441,
#        0.03137481, 0.15575352, 0.02040334, 0.11299331, 0.0851646 ]), array([0.06390404, 0.08393197, 0.05111483, 0.18046371, 0.14918022,
#        0.15860382, 0.18325067, 0.12955074]), array([0.12969034, 0.10117663, 0.0232441 , 0.11676307, 0.12306615,
#        0.08901147, 0.05658217, 0.07389923, 0.0378592 , 0.09780079,
#        0.15090685])]
# Story with candidates (First sentence is each array is good)
# [['Carrie had just learned how to ride a bike.', 'She looked around frantically.', 'The owner warned her that the car was tricky.', "She didn't know what to wear.", 'He almost gave up.'], ["She didn't have a bike of her own.", 'Minutes later, Maurice realized the clown had stolen his phone.', 'They had to make the best tasting one.', "Kya returned the wallet to the girl she'd stolen it from.", 'Jim wanted to learn how to paint.', 'He studied for two weeks.', 'She decided to use the money for more tickets.', 'A man took out a big bet against the Jets.'], ["Carrie would sneak rides on her sister's bike.", 'Sadly, this made Riley very uncomfortable.', "It was Tyler's first day of Kindergarten.", 'Beth had to choose between universities.', 'His car keys were on the refrigerator shelf.'], ['She got nervous on a hill and crashed into a wall.', 'He was not satisfied with what he came out with.', 'Erick was in 2nd grade', 'Cayla finally saw a doctor and explained her problems.', 'She almost gave up, but then she grinned instead.', 'I searched all Chevrolet dealers in the United States.', 'I have had him for 6 months now.', 'Leslie started working on getting the pit filled.', 'On his 16th birthday Jane convinced him to allow her to measure him', 'He had lots of cavities.'], ['The bike frame bent and Carrie got a deep gash on her leg.', 'She gives her customers many options.', 'I always had a fear of needles.', 'Gina was almost within reach of the door.', 'They sat together everyday.', 'He applied at several stores near his home.', 'In order to do that, Jacob tried to kickflip down a set of 6 stairs.', 'There was a pedestrian crossing that was very busy.', 'The dog was going nuts!', 'Without telling anyone, she swam out farther, and lost her footing.']]
# BERT Scores
# [array([[9.99995589e-01, 3.49066849e-03, 9.80508924e-01, 5.90163702e-03,
#         9.99922872e-01, 3.53041664e-03, 9.99966264e-01, 5.98968007e-03],
#        [9.99928951e-01, 9.66019725e-05, 1.14406622e-03, 3.26042483e-03,
#         6.41780134e-05, 6.79918685e-06, 1.63020976e-02, 7.31964246e-04],
#        [9.99977946e-01, 9.98308301e-01, 9.98938382e-01, 9.99353111e-01,
#         8.53287580e-04, 1.61253090e-04, 9.99974251e-01, 9.93137121e-01],
#        [9.99971509e-01, 5.30373072e-04, 1.06876847e-04, 1.42037384e-02,
#         1.25397858e-03, 4.62459611e-05, 9.99413729e-01, 8.65944312e-04],
#        [9.98968720e-01, 9.98941720e-01, 9.97791290e-01, 1.14774320e-03,
#         9.99730289e-01, 9.99634147e-01, 4.19635442e-04, 9.97127116e-01]]), array([[9.99993682e-01, 1.99454010e-01, 1.57272711e-03, 9.94464934e-01,
#         9.98517215e-01],
#        [4.02627775e-05, 1.06183339e-04, 1.76249996e-05, 1.52418888e-05,
#         9.99254644e-01],
#         1.11699372e-03, 9.95227575e-01, 5.38632521e-05, 7.72382627e-05,
#         1.20022654e-04, 1.32562582e-05],
#        [9.99960184e-01, 2.47576763e-03, 1.38758740e-04, 9.96463954e-01,
#         9.99404430e-01, 1.69313897e-03, 9.95180726e-01, 1.08046609e-03,
#         1.08808903e-02, 9.99842644e-01],
#        [1.64623925e-04, 6.77547604e-03, 1.62151686e-04, 7.25133359e-05,
#         9.99982238e-01, 9.99959230e-01, 9.99885559e-01, 5.31739963e-04,
#         1.65804312e-01, 7.90372069e-05],
#        [1.31905265e-02, 1.11366629e-04, 9.96413887e-01, 7.03461375e-03,
#         2.36355420e-02, 6.05650961e-01, 9.83110309e-01, 8.26123059e-01,
#         9.33008566e-02, 1.12892722e-03]])]
# Marginals
# [array([0.24373983, 0.06520865, 0.24309569, 0.14589753, 0.3020583 ]), array([3.18885430e-01, 2.24545495e-02, 1.10996823e-01, 2.38088836e-05,
#        1.21663781e-01, 8.04813584e-02, 2.47387224e-01, 9.81070261e-02]), array([0.34844696, 0.0626496 , 0.12454877, 0.36380249, 0.10055219]), array([3.02734835e-01, 6.86887259e-02, 1.97281997e-01, 1.62448220e-01,
#        6.73945152e-03, 3.16144643e-02, 3.60344105e-06, 9.31919036e-02,
#        9.15860171e-02, 4.57107822e-02]), array([0.12193108, 0.01958768, 0.05784472, 0.04468619, 0.22011848,
#        0.13971035, 0.17678888, 0.06973405, 0.03054367, 0.1190549 ])]
# Story with candidates (First sentence is each array is good)
# [['Morgan enjoyed long walks on the beach.', "Maddie's mom took her to get her puppy as her reward.", 'That night he snuggled with his wife on the bug free porch.', 'Jake lost balance and fell.', 'This arrangement worked out perfectly for all three of them.', 'His parents discussed it and decided to buy him the game.', 'rainy leaked through the roof.', 'He was so much work.', "She didn't know how to ride it without training wheels.", 'They never thought a tornado would actually hit.'], ['She and her boyfriend decided to go for a long walk.', 'Carl finds old dirty sneakers in his closet.', 'One day i overslept and was late for work.', 'In 2013 my sister in law went to Atlantic City.', 'The mouse was coming in from the rain whenever it rained.', 'He went into the cave, and he was terrified when he found a shark!', 'Sam needed to go to work one snowy morning', 'Mandy was invited to a party.', 'He told Charles he was hired because the boss liked his shined shoes.', 'Eli was scared out of his wits and shot them all!'], ['After walking for over a mile, something happened.', 'Lisa called him constantly for two weeks.', 'Everything he did on it was slow.', "His dad listened, but didn't say anything.", 'Amy had heart palpitations after a lot of caffeine.'], ['Morgan decided to propose to her boyfriend.', 'I practiced for a whole day.', 'Sandy was soon back to normal, regularly going out and enjoying life.', 'I wanted to run a computer program.', 'She took a bite of an apple one day.', 'I waited and waited until it was my turn.', 'Abe feared rejection so much it was affecting his love life.', 'Bob just bought a new couch for the living room.'], ["Her boyfriend was upset he didn't propose to her first.", 'Bea loved to paint and she hoped to be a famous artist one day.', "Jason didn't like cats.", 'She made it so that on her days she got her favorite types of candy.', 'Tom and Diane have been married for years.', 'The day of the robbery I got sick and away from the currency exchange.', "He told me he had just listened to Beethoven's Ninth."]]
# BERT Scores
# [['Jane was working at a diner.', 'One day during their walk the dog escaped from his leash.', 'One day Rex met a nice woman who liked him despite his shortcomings.', 'I walked into the kitchen to prepare the cake.', 'Ed told him that the car was in the bottom of the lake.', 'When the morning came he knew he had conquered his fear.', "It was Amy's first day in the first grade."], ['Suddenly, a customer barged up to the counter.', 'After an hour of swimming, something terrible happened.', "I was six and it was Christmas and I'd already opened all my presents.", 'Everyone had a great day bowling and seeing friends.', 'It took him several months, but he eventually earned enough money.', "I really fantasized that I'd find a leprechaun in there.", 'She took a bite of an apple one day.', 'A couple decided to make their own pottery.', 'She decided to go to the show anyway.'], ['He began yelling about how long his food was taking.', 'He always asked his mother to leave a nightlight on at night.', 'I bought it and it was very tasty.', 'Sam remembered there were old cans of food in the basement.', 'Once at the store, I walked around and selected my groceries.', 'Turning his computer on he realized there was a lot of work up!', 'Everyone who betted for Karly won a lot of money.', 'Audrey surprisingly fell in love with their restaurant and food.'], ["Jane didn't know how to react.", 'However, he is happy to be eating healthy food.', 'Carrie became offended by the comment and ran home.', 'The children ate three plates of food each.', 'They spent all day practicing', 'Sophie had a great time trick-or-treating in her dragon costume.', 'John dropped the soup when he grabbed it from the microwave.'], ['Luckily, her coworker intervened and calmed the man down.', "Katie went to a girl's camp across the lake from a boy's camp.", 'Dan hit his golf ball and watched it go.', 'Everyone was mortified.', 'Dismayed, Terry and his friend settled on a different movie.', 'The fire was getting worse, but I saved an old lady who passed out.', 'She woke up at five every morning to run six miles.', 'One year, a major hurricane was announced on the news.']]
# BERT Scores
# [array([[9.99979854e-01, 1.92555948e-03, 1.08767592e-03, 9.95873630e-01,
#         3.12489457e-02, 1.94663124e-03, 9.99989986e-01, 9.99960303e-01,
#         9.93003070e-01],
#        [9.93277371e-01, 9.99565899e-01, 4.66967467e-05, 9.99801338e-01,
#         1.21062972e-01, 9.51925322e-05, 9.99969840e-01, 9.99958634e-01,
#         1.01247421e-02],
#        [2.35565230e-02, 4.56703856e-04, 1.46015096e-04, 9.98584867e-01,
#         9.99956131e-01, 2.80904987e-05, 9.99984264e-01, 9.99912024e-01,
#         7.89131224e-03],
#        [9.99845624e-01, 8.24407689e-05, 9.99978065e-01, 3.41442451e-02,
#         7.28656050e-06, 9.99923587e-01, 5.37128617e-05, 9.15869678e-05,
#         6.56586999e-05],
#        [8.02155118e-04, 9.99980330e-01, 1.14248605e-05, 1.90750055e-04,
#         1.98008362e-04, 1.20875804e-04, 1.27122703e-05, 1.65623700e-04,
#         5.95433958e-05],
#        [6.99432509e-04, 9.99939084e-01, 8.48687705e-06, 3.98854405e-04,
#         7.10928580e-05, 7.56490954e-06, 9.35340868e-05, 1.78242059e-04,
#         2.26730444e-05],
#        [1.81218178e-03, 9.89358306e-01, 9.99963403e-01, 9.99979734e-01,
#         2.27578683e-04, 1.90172184e-04, 9.99982953e-01, 9.93796825e-01,
#         9.99547303e-01]]), array([[9.99992132e-01, 7.22296099e-05, 1.19970013e-04, 1.05368579e-03,
#         1.80892981e-04, 1.72556742e-04, 2.71961908e-04, 4.00824472e-03],
#        [9.99531865e-01, 4.56801463e-05, 2.50287849e-05, 9.97237206e-01,
#         1.31647335e-04, 1.18192074e-04, 3.74268420e-04, 6.38805621e-04],
#        [6.59107463e-04, 2.14075227e-03, 9.99970317e-01, 1.43399142e-04,
#         9.99219537e-01, 9.91992176e-01, 9.99377728e-01, 9.97956872e-01],
#        [9.65303719e-01, 9.99975562e-01, 4.13898891e-03, 7.92833567e-02,
#         1.68056097e-02, 6.82373717e-02, 9.99213815e-01, 9.93042469e-01],
#        [2.62897671e-03, 1.27117935e-04, 9.94153559e-01, 9.99217749e-01,
#         9.99732435e-01, 1.53570159e-04, 4.62143034e-05, 4.15187707e-04]])]
# Marginals
# [array([0.21450788, 0.21870298, 0.24174132, 0.04512385, 0.02541268,
#        0.0254156 , 0.22909569]), array([0.05990415, 0.10121721, 0.0231973 , 0.24626915, 0.08886137,
#        0.01162875, 0.2444592 , 0.16697744, 0.05748543]), array([0.24055409, 0.08211962, 0.09082959, 0.08853479, 0.02670203,
#        0.03842723, 0.22177397, 0.21105868]), array([0.02283636, 0.04259334, 0.14534535, 0.13720931, 0.2959131 ,
#        0.20853256, 0.14756998]), array([0.084397  , 0.21043399, 0.12203467, 0.09360458, 0.16805964,
#        0.07556892, 0.09959271, 0.14630847])]
# Story with candidates (First sentence is each array is good)
# [['I was talking to my crush today.', 'Bogart stopped eating bacon.', 'With 10 seconds left in the game, Rick scored a goal on a breakaway!', 'Ronnie was excited to be in the top two.', 'Kelly wanted to be a unicorn for Halloween.', 'I was not comfortable.', 'He spent most of his time alone in his apartment.', 'Josh loves to eat crepes.', 'She worked for hours typing each new name, one at a time.', 'Colleen made sure she knew how to do it before leaving.'], ['She continued to complain about guys flirting with her.', 'Chris and Aimee were newlyweds, and wanted to buy a house.', 'He had to wear a cast for 6 weeks.', 'My family and I enjoyed the pie for dessert.', 'He worked at an electronic store.', 'Charles wanted to watch his favorite show on the television.', 'Jim brought James home and fed him dog treats.', "Leslie's boyfriend was overseas making money.", 'Her best friend smoked as well.', 'My dad got a job in the city.', 'Riley loved grape flavored candy.'], ['I decided to agree with what she says and listened to her patiently.', 'Jess stopped browsing and called for her kitty.', 'I came to school drowsy since I spent all night studying for exams.', 'Instead, they jealously asked if Danny wanted to trade his humble bag.'], ['After I got home, I got a text from her.', 'Jenny was at the site with them one day.', 'We had dinner in Brooklyn tonight.', 'She tripped over her shoe lace.', 'Somehow she had messed up and her hair came out completely red.', 'The dog could not swim.', "She didn't want to get stung, so she pulled off the road.", 'Chuck reclined on the back porch as he sipped his morning coffee.', 'They were expecting a child very soon.', 'While there, he made plans to hike a mountain, to Machu Picchu.'], ['She asked if we can hang out tomorrow.', 'I had to buy dental insurance out of pocket.', 'He had been entrusted to make sure the burgers were perfect.', 'My son was yelling something at me.', 'Brenda walked away and now she is the saddest girl out of everyone.', 'Gina began to walk down the street.', 'Paul found himself in over his head and called a tow truck for repair.']]
# BERT Scores
# [array([[9.99592602e-01, 9.82466936e-01, 1.25825824e-03, 7.65217781e-01,
#         5.83029306e-03, 2.32111569e-03, 3.82279715e-04, 9.99710500e-01,
#         2.65911163e-04, 9.85018551e-01, 8.11209437e-03],
#        [1.37506030e-03, 1.33958366e-02, 9.98990953e-01, 9.99812067e-01,
# [['Frank had been drinking beer.', 'Eventually they stopped being friends.', 'She started by cleaning out all of the trash.', 'There once was an Opossum that lived under my brothers front porch.', 'Steve wanted a job!', 'Her mood changed quickly when her friends jumped out to surprise her.', 'He began to tell a funny story about his past.'], ['He got a call from his girlfriend, asking where he was.', 'I arrived at the store and went inside.', "Anita's son loved helicopters.", 'Many storms would come through every year.', 'I was excited and ready to go when it started to rainy.', 'The weather caused everyone in the crowd to seek shelter.', "Kim wasn't a very good cook.", 'Frankie had Christmas shopping to do.'], ['Frank suddenly realized he had a date that night.', 'A man took out a big bet against the Jets.', 'Luckily it only lasts a minute, and she has her new pair of shoes on.', 'His parents told him not to play near the ant hills in the backyard.', 'Laura was patiently awaiting the results of her test.', 'Her mood changed quickly when her friends jumped out to surprise her.', "Her family didn't have money for lessons.", "The next time a storm came, Jim didn't bother boarding up.", 'He was hoping to get the Super Mario Maker game for Christmas.', 'He put them into a bucket and dragged them to the curb.', 'That Monday he brought them in, and his coworkers hated them.'], ['Since Frank was already a bit drunk, he could not drive.', 'Glancing at her watch, Gail became agitated.', 'Then he would chase the ball and hit it.', 'I go to see games any time I get the chance.', 'She decided to switch to formula feeding.', 'The property was not doing well financially.', 'I bought a box of packing tape from Amazon.', 'A restaurant charged me too much by mistake.', 'Erin and Sara had been making fun of Amy in class one day.'], ['Frank spent the rest of the night drinking more beers.', 'Phil spends time in the army and the time has come to go to war.', 'She was sad when they gave her a doll instead.', 'Eventually, he graduated with a degree in sculpture.']]
# BERT Scores
# [array([[9.99938965e-01, 5.02436981e-03, 9.96225953e-01, 1.36914750e-04,
#         1.07757129e-04, 2.68147904e-02, 5.17514185e-04, 1.51696592e-03],
#        [9.99942899e-01, 1.78914685e-02, 9.97438908e-01, 7.05399842e-04,
#         1.63875858e-03, 7.08377687e-04, 9.98679817e-01, 9.99369204e-01],
#        [3.36315745e-04, 4.56286548e-03, 5.50420082e-04, 1.44980280e-04,
#         9.56514850e-02, 2.19635735e-03, 9.99839783e-01, 5.62977374e-01],
#        [3.88199260e-05, 9.98452544e-01, 9.99428451e-01, 2.47794017e-03,
#         9.88149285e-01, 1.66544016e-03, 1.24905855e-04, 2.96973703e-05],
#        [9.99822438e-01, 9.94093239e-01, 9.98334706e-01, 1.58416922e-03,
#         1.70272827e-01, 4.53822693e-04, 2.96882144e-03, 9.98130262e-01],
#        [5.51275880e-05, 4.39932104e-03, 5.56316273e-03, 4.30147018e-04,
#         4.37938259e-04, 9.99065220e-01, 9.99665380e-01, 9.99685049e-01],
#        [9.99943256e-01, 1.26930280e-02, 9.93841529e-01, 7.51706725e-03,
#         4.55363141e-03, 9.85832214e-01, 3.44737782e-04, 1.24210797e-04]]), array([[9.99968171e-01, 5.81242703e-03, 2.00197846e-05, 9.99389648e-01,
#         1.19370259e-02, 2.72219739e-04, 5.97258404e-05, 9.99868989e-01,
#         9.99901295e-01, 1.19756398e-04, 4.22855699e-03],
#        [1.16792755e-04, 1.01964618e-03, 1.21998173e-05, 1.35732887e-04,
#         9.96703923e-01, 3.94235743e-04, 2.30318474e-04, 2.79375017e-05,
#         2.16130093e-02, 3.26315960e-04, 1.05022045e-05],
#         6.48472458e-02],
#        [1.02834259e-04, 1.55900361e-05, 3.93762166e-05, 1.15249818e-02,
#         3.86449229e-03, 6.84972256e-05, 2.89037678e-04, 4.76482324e-03,
#         2.87584116e-05],
#        [3.46055254e-04, 3.44688859e-04, 1.91984966e-01, 1.92317218e-02,
#         9.99752343e-01, 9.98311520e-01, 9.99910474e-01, 3.60346469e-03,
#         8.87075148e-04],
#        [2.47425120e-03, 3.81932384e-03, 9.93477702e-01, 1.31751727e-02,
#         9.98058498e-01, 4.07078514e-05, 4.94272623e-04, 5.60556166e-02,
#         9.98038709e-01],
#        [9.85520303e-01, 9.22912598e-01, 2.80057490e-02, 9.28364869e-04,
#         8.97937629e-04, 9.99907732e-01, 9.99871612e-01, 1.32822338e-03,
#         9.95368898e-01]])]
# Marginals
# [array([0.13761152, 0.08636203, 0.1116871 , 0.09227597, 0.04364728,
#        0.07158765, 0.10981688, 0.11015795, 0.11479111, 0.12206251]), array([0.05399934, 0.05024013, 0.07356567, 0.0760924 , 0.28366243,
#        0.087721  , 0.05672648, 0.06061255, 0.10597758, 0.15140244]), array([0.10361645, 0.0103425 , 0.32037227, 0.2852246 , 0.0947718 ,
#        0.00892821, 0.08805692, 0.08868724]), array([2.87225089e-01, 4.04348135e-01, 3.15792801e-02, 2.17285845e-05,
#        1.16020199e-01, 1.53045349e-01, 7.76021870e-03]), array([0.10283903, 0.04700883, 0.10178602, 0.09999395, 0.20271409,
#        0.08286925, 0.13887667, 0.11723289, 0.10667927])]
# Story with candidates (First sentence is each array is good)
# [['Sally was happy when her widowed mom found a new man.', 'People then decided to start making fun of Vlad.', 'Yelena loved to read books.', 'Cindy no longer had to worry about any bullies.', "He wondered if he'd be able to make new friends, or keep his old ones.", 'She hung up and I realized that I needed experience to get a job.', "She went to a grocery store, but they didn't have mint either."], ["She discovered her siblings didn't feel the same.", 'All the dust that kicked up made him cough.', "When they went inside, Billy's mom had hot cocoa for them.", "She found out he was fired and was furious that he didn't tell her."], ["Sally flew to visit her mom and her mom's new husband.", 'Jane passed a small park-like zoo she remembered visiting as a child.', 'We live in Cambridge, Massachusetts.', 'He never had time to clean up.', 'Francis was so proud he was finally helping at the family farm.', 'It made all the difference!', 'The secretary informed Sandy that they were from a secret admirer.', 'Rita started playing and became very good at golf.', 'Jeff slammed on the breaks.'], ['Although her mom was obviously in love, he was nothing like her dad.', 'She decided to give her friend an ultimatum.', 'A week later, his wife called him to say that she changed her mind.', 'Betty went to the beach and made friends with a surfer.', 'Frustratingly, the garage door opener shorted out.', 'Erica wanted to help her mom this Thanksgiving.', 'She was in a hospital.', 'She pulled out a bottle of bug spray and applied it liberally.'], ["Sally went home and wondered about her parents' marriage.", 'She practiced all week.', 'Hillary and her friends drove to the woods to go camping.', "His mom assured him that ghosts weren't real.", 'He was impressed with her efforts and they were great.', 'Pandy was enjoying herself until she noticed a rabbit nearby.', 'When he got there, the sub was six feet long!', 'She saw that the ice cream had become freezer-burned!', 'After a while, she accepted a job in Denver and moved there.']]
# BERT Scores
#        [9.99758184e-01, 9.78190899e-01, 9.99982357e-01, 3.99180462e-05,
#         3.93407361e-04, 9.90447283e-01, 9.24100823e-06, 3.47707915e-04,
#         9.98564541e-01],
#        [9.99951243e-01, 9.93811190e-01, 9.99930620e-01, 9.99810278e-01,
#         9.99965429e-01, 1.48596402e-04, 1.57610513e-04, 1.27374986e-02,
#         9.99887824e-01],
#        [9.99988794e-01, 9.99981165e-01, 9.99991059e-01, 7.76278903e-04,
#         9.99987841e-01, 9.99705732e-01, 7.79249473e-04, 1.95242912e-01,
#         9.99978304e-01],
#        [4.71967738e-03, 9.03226316e-01, 9.98857260e-01, 3.49423790e-04,
#         9.00555387e-05, 1.76839691e-04, 4.83999640e-04, 9.99955893e-01,
#         1.55576581e-05],
#        [9.99942183e-01, 9.99914646e-01, 9.99992728e-01, 7.04962076e-05,
#         2.01552827e-03, 4.25323196e-05, 4.39388259e-06, 3.95337306e-02,
#         9.84040439e-01],
#        [9.99351084e-01, 9.87187266e-01, 9.95852828e-01, 2.21606284e-01,
#         1.80209187e-04, 5.40182409e-05, 8.13348306e-05, 2.83908341e-02,
#         9.99631405e-01],
#        [4.67243930e-03, 9.99909639e-01, 3.75802605e-03, 1.03316952e-05,
#         9.99959469e-01, 9.99878645e-01, 2.58444488e-05, 9.99830604e-01,
#         5.62548230e-05]])]
# Marginals
# [array([3.18022242e-01, 4.06877301e-04, 1.77704544e-01, 1.12081309e-01,
#        7.38574744e-02, 4.74148993e-05, 3.17880138e-01]), array([0.43332311, 0.00435929, 0.28055303, 0.28176457]), array([3.12543299e-01, 3.07122659e-02, 4.91880261e-05, 4.02734504e-02,
#        2.18566795e-01, 1.94859097e-01, 3.57732465e-02, 1.66651771e-01,
#        5.70886032e-04]), array([0.18309589, 0.14176763, 0.18398081, 0.27926575, 0.02359172,
#        0.1065065 , 0.07377884, 0.00801286]), array([1.84823404e-01, 1.56429784e-01, 1.92832962e-01, 7.10576275e-02,
#        1.14314330e-01, 7.54169650e-02, 4.61925958e-05, 2.08605784e-02,
#        1.84218155e-01])]
# Story with candidates (First sentence is each array is good)
# [['Dan hit his golf ball and watched it go.', 'He slowed down just enough for people to hop on the bus.', 'I looked at my TV and saw independence day was on.', 'Audrey was afraid to try new foods.', 'Minutes later, Maurice realized the clown had stolen his phone.', 'He was quite hungry but sort of enjoyed the feeling.'], ['The ball bounced on the grass and into the sand trap.', 'Bob just bought a new couch for the living room.', 'She continued to complain about guys flirting with her.', "He didn't see her for the whole day.", 'But when she looked at the sky, she saw its beauty with great clarity.'], ['Dan pretended that his ball actually landed on the green.', 'Matt and Jamie got soaked in the rain.', 'One day they all helped Emily learn to ride a bike.', 'She was finally able to buy the computer she needed.', 'He really wanted to be a play writer, however.', 'Maddie really wanted a puppy.', 'Jim was watching tv and eating chocolate pudding.', 'She took it and failed.', 'He joins a group with others that suffer from Acrophobia.', 'He worked full time while his friends were out enjoying the summer.'], ['His friends were not paying attention so they believed him.', 'Sally then met her friends in real life and they are now very close.', 'When she was finished she realized she no longer liked the furniture.', 'Jason decides to buy an Apple Macbook.', 'Finally he found a red truck that he liked.', 'So Matt thought of a way to play ball like he wanted.', 'Frustratingly, the garage door opener shorted out.', 'She met a friend and played.', "Amy didn't care about the yelling, but was hurt to lose the shorts."], ['Dan snuck a ball on the green and made his putt from 10 feet.', 'He finally understood how the other kids felt.', 'She got fitted for a pair that night.', 'He decided to move to Florida because of its nice weather.', 'They called the restaurant to tell them.', 'The comedian panicked and tried some of his best material.', 'We live in Cambridge, Massachusetts.']]
# BERT Scores
# [array([[9.99992967e-01, 2.34559271e-02, 7.71361636e-04, 9.98902202e-01,
#         3.41025188e-05],
#        [6.05486217e-04, 1.91220053e-04, 6.60358462e-04, 9.75292385e-01,
#         3.51052840e-05],
#        [2.06517943e-04, 9.99951720e-01, 2.33549182e-03, 5.00748174e-05,
#         6.17779415e-06],
#        [9.37822973e-04, 9.84781265e-01, 9.99963880e-01, 4.13771570e-02,
#         9.93075848e-01],
#        [3.95196024e-04, 5.45718591e-04, 5.79951811e-05, 9.86603379e-01,
#         5.79422294e-06],
#        [5.83335400e-01, 1.19960874e-01, 4.22317826e-04, 9.98089135e-01,
#         4.13757043e-05]]), array([[9.99994278e-01, 9.99909401e-01, 3.73759819e-03, 1.29995737e-04,
#         1.19815968e-05, 6.44626387e-04, 8.91424343e-03, 9.99457538e-01,
#         6.42686609e-06, 5.45312243e-04],
#        [2.32320177e-04, 9.67470944e-01, 9.97557521e-01, 9.99079704e-01,
#         1.72029482e-03, 7.26239698e-04, 9.99980330e-01, 3.54911681e-05,
#         1.85874509e-04, 9.99852777e-01],
#        [9.94855523e-01, 2.59493850e-02, 9.99946475e-01, 9.99911189e-01,
#         2.48599565e-04, 9.99552310e-01, 9.65254366e-01, 7.16973007e-01,
#         7.33740380e-05, 2.49383645e-03],
#        [4.18744266e-01, 9.99447167e-01, 3.35316872e-04, 9.99645710e-01,
#         7.15498289e-04, 1.77341811e-02, 9.99888420e-01, 7.53779823e-05,
#         1.42484423e-04, 9.99920368e-01],
#        [7.70759507e-05, 2.62848064e-02, 1.28186692e-03, 2.90275959e-04,
#         7.16901195e-06, 4.57171845e-05, 3.79351870e-04, 3.85695659e-02,
#         5.49353763e-06, 1.40506381e-05]]), array([[9.99989748e-01, 1.35064214e-01, 1.21973981e-05, 9.96675253e-01,
#         1.52175516e-01, 9.99991179e-01, 2.55131023e-03, 1.05521418e-02,
#         9.99940753e-01],
#        [9.80214059e-01, 9.94544148e-01, 5.83713663e-05, 9.96753871e-01,
#         3.17290146e-03, 9.99992967e-01, 9.97596323e-01, 9.98657107e-01,
#         9.99954700e-01],
#        [2.31592823e-02, 9.99983430e-01, 1.29435502e-03, 9.99711573e-01,
#         3.08664422e-03, 9.99939680e-01, 5.92543855e-02, 9.99985695e-01,
#         9.99924064e-01],
#        [6.12747826e-05, 9.99984860e-01, 9.99968052e-01, 9.99986649e-01,
#         1.54172652e-03, 6.58745050e-01, 9.89400566e-01, 9.99989033e-01,
#         3.54979595e-04],
#        [9.99421597e-01, 3.63172055e-03, 2.90907083e-05, 2.66145617e-02,
